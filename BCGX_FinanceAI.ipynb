# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cwd = os.getcwd()
df = pd.read_csv(cwd + "\\10KData.csv")
print(df)
# Out:
#      Company  Year  Total Revenue  Net Income  Total Assets  \
# 0      Apple  2024         391035       93736        364980
# 1      Apple  2023         383285       96995        352583
# 2      Apple  2022         394328       99803        352755
# 3      Tesla  2024          97690        7153        122070
# 4      Tesla  2023          96773       14974        106618
# 5      Tesla  2022          81462       12587         82338
# 6  Microsoft  2024         245122       88136        512163
# 7  Microsoft  2023         211915       72361        411976
# 8  Microsoft  2022         198270       72738        364840
#
#    Total Liabilities   Cash Flow from Operating Activities
# 0              308030                               118254
# 1              290437                               110543
# 2              302083                               122151
# 3               48390                                14923
# 4               43009                                13256
# ...

# %%
df = df.sort_values(by=["Company", "Year"]).reset_index(drop=True)

# Calculate % growth for each column
df["Revenue Growth (%)"] = df.groupby("Company")["Total Revenue"].pct_change() * 100
df["Net Income Growth (%)"] = df.groupby("Company")["Net Income"].pct_change() * 100
df["Asset Growth (%)"] = df.groupby("Company")["Total Assets"].pct_change() * 100
df["Liabilities Growth (%)"] = df.groupby("Company")["Total Liabilities "].pct_change() * 100
df["Cash Flow Growth (%)"] = df.groupby("Company")["Cash Flow from Operating Activities"].pct_change() * 100
df.fillna(0, inplace=True)

print(df)
# Out:
#      Company  Year  Total Revenue  Net Income  Total Assets  \
# 0      Apple  2022         394328       99803        352755
# 1      Apple  2023         383285       96995        352583
# 2      Apple  2024         391035       93736        364980
# 3  Microsoft  2022         198270       72738        364840
# 4  Microsoft  2023         211915       72361        411976
# 5  Microsoft  2024         245122       88136        512163
# 6      Tesla  2022          81462       12587         82338
# 7      Tesla  2023          96773       14974        106618
# 8      Tesla  2024          97690        7153        122070
#
#    Total Liabilities   Cash Flow from Operating Activities  \
# 0              302083                               122151
# 1              290437                               110543
# 2              308030                               118254
# 3              198298                                89035
# 4              205753                                87582
# ...

# %%
data.to_csv('bcg-financial-data.csv')
# Out:
# C:\Users\Neel\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Financial data saved to financial_data.xlsx

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))

# Coolumns to graph
columns_to_plot = [
    "Total Revenue", 
    "Net Income", 
    "Total Assets", 
    "Total Liabilities ", 
    "Cash Flow from Operating Activities"
]

# Create a graph for each column
for col in columns_to_plot:
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=df, x="Year", y=col, hue="Company", marker="o")
    plt.title(f"{col} by Company Over Years")
    plt.xlabel("Year")
    plt.ylabel(col)
    plt.legend(title="Company")
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Neel\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Neel\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Neel\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...
